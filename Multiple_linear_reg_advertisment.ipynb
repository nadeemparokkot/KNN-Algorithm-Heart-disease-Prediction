# %%
import numpy as np
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/advertising_data")
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.isna().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
#input and output
x=df.iloc[:,:-1]
y=df.iloc[:,-1]
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
#to plot graph using seaborn(no matplotlib) 
#TV sales plotting
import seaborn as sns
sns.regplot(x=df['TV'],y=y,color='g')

# %%
#radio sales plotting
sns.regplot(x=df['Radio'],y=y)

# %%
#newspaper sales plottting
sns.regplot(x=df['Newspaper'],y=y,color='r')

# %%
#train and test
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.30)
ytest
# Out:
# 135    11.6
# 41     17.1
# 82     11.3
# 25     17.0
# 198    25.5
# 28     18.9
# 111    21.8
# 114    14.6
# 49      9.7
# 77     14.2
# 151    11.6
# 164    11.9
# 42     20.7
# 18     11.3
# 31     11.9
# 128    24.7
# 150    16.1
# 78      5.3
# 85     20.2
# 55     23.7
# 146    18.2
# 100    16.7
# 161    13.3
# 199    18.4
# 53     21.2
# 195     7.6
# 109    19.8
# 32     13.2
# 17     24.4
# 98     25.4
# 124    19.7
# 168    17.1
# 123    15.2
# 88     12.9
# 183    26.2
# 131    17.7
# 134    10.8
# 19     14.6
# 145    10.3
# 149    10.1
# 139    20.7
# 130     1.6
# 147    25.4
# 178    16.8
# 26     15.0
# 129     9.7
# 176    20.2
# 107    12.0
# 73     11.0
# 39     21.5
# 87     16.0
# 155     3.2
# 166     8.0
# 103    19.7
# 93     22.2
# 188    20.9
# 117     9.4
# 90     14.0
# 169    20.0
# 152    16.6
# Name: Sales, dtype: float64

# %%
#model creation regression
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(xtrain,ytrain)
ypred=model.predict(xtest)
ypred
# Out:
# array([12.51008046, 17.86395709, 10.98828458, 19.66035642, 24.33456468,
#        21.30171079, 22.03991315, 13.87631081,  9.59387716, 14.49544142,
#        12.10280884, 12.96875837, 24.02592228, 10.81254587, 12.69021735,
#        22.20161401, 21.54502151,  8.37515373, 16.93417674, 20.51732734,
#        18.90909854, 17.22772136, 13.00287787, 18.60520258, 19.30417774,
#         7.41383277, 21.8120707 , 10.2637665 , 24.06610493, 24.84602979,
#        20.28388698, 18.76969714, 15.28818357, 11.84291575, 24.60320075,
#        19.49580475, 10.45859644, 15.44044725, 12.87303397,  9.99627832,
#        19.74589619,  9.13023776, 23.05790778, 20.2518687 , 15.82239651,
#         9.16340946, 21.62656522,  9.83249977, 12.4525958 , 21.1719332 ,
#        14.73659209,  6.44185715,  9.74065904, 16.98375435, 21.91154692,
#        22.15940416,  9.19824979, 12.8522172 , 21.69766946, 18.1843356 ])

# %%
print(model.predict([[110.4,86.5,87.6]]))
# Out:
# [19.24342517]
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#y=m1x1+m2x2+.....+mnxn+c
print('constant',model.intercept_)
print('Slop is',model.coef_)
print('TV slop is',model.coef_[0])
print('radio slop is',model.coef_[1])
print('newspaper slop is',model.coef_[2])
list(zip(x,model.coef_))#to show 3 combine
# Out:
# constant 5.069336520581819
# Slop is [ 0.05484058  0.1037144  -0.00972155]
# TV slop is 0.05484058456339698
# radio slop is 0.10371440137081121
# newspaper slop is -0.009721547995896536
# [('TV', 0.05484058456339698),
#  ('Radio', 0.10371440137081121),
#  ('Newspaper', -0.009721547995896536)]

# %%
#create a data frame Actual value and predicted value
df1=pd.DataFrame({"Actual_value":ytest,'Predicted_value':ypred})
df1
# Out:
#      Actual_value  Predicted_value
# 135          11.6        12.510080
# 41           17.1        17.863957
# 82           11.3        10.988285
# 25           17.0        19.660356
# 198          25.5        24.334565
# 28           18.9        21.301711
# 111          21.8        22.039913
# 114          14.6        13.876311
# 49            9.7         9.593877
# 77           14.2        14.495441
# 151          11.6        12.102809
# 164          11.9        12.968758
# 42           20.7        24.025922
# 18           11.3        10.812546
# 31           11.9        12.690217
# 128          24.7        22.201614
# 150          16.1        21.545022
# 78            5.3         8.375154
# 85           20.2        16.934177
# 55           23.7        20.517327
# 146          18.2        18.909099
# 100          16.7        17.227721
# 161          13.3        13.002878
# 199          18.4        18.605203
# 53           21.2        19.304178
# 195           7.6         7.413833
# ...

# %%
#perfomance evaluation(stight line(regression))
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
print("MAE",mean_absolute_error(ytest,ypred))
print("MSE",mean_squared_error(ytest,ypred))
rmse=np.sqrt(mean_squared_error(ytest,ypred))
print("RMSE",rmse)
print("r2_score",r2_score(ytest,ypred))
# Out:
# MAE 1.494693147221782
# MSE 4.11381834025388
# RMSE 2.0282549988238365
# r2_score 0.8718653538314736

# %%
#model error
from sklearn.metrics import mean_absolute_percentage_error
print("percentage",mean_absolute_percentage_error(ytest,ypred))
# Out:
# percentage 0.18264717369513833
